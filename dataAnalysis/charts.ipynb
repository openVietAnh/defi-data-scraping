# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import matplotlib.dates as md
from utils import plot_multiple_files

# %%
files = [
    ("../csvData/utilizationRate/DAI-Utilisation rate-v2.csv", "b-"),
    ("../csvData/utilizationRate/USDC-Utilisation rate-v2.csv", "r-"),
    ("../csvData/utilizationRate/USDT-Utilisation rate-v2.csv", "g-"),
    ("../csvData/utilizationRate/WBTC-Utilisation rate-v2.csv", "k-"),
    ("../csvData/utilizationRate/WETH-Utilisation rate-v2.csv", "y-")
]
plot_multiple_files(files, "Date", "Utilization rate (%)", "Five tokens utilization rate", "center left", 0, 2, True)

# %%
files = [
    ("../csvData/totalValueLocked/DAI-6m-TLV-v2.csv", "b-"),
    ("../csvData/totalValueLocked/USDC-6m-TVL-v2.csv", "r-"),
    ("../csvData/totalValueLocked/USDT-6m-TVL-v2.csv", "g-"),
    ("../csvData/totalValueLocked/WBTC-6m-TVL-v2.csv", "k-"),
    ("../csvData/totalValueLocked/WETH-6m-TVL-v2.csv", "y-")
]
plot_multiple_files(files, "Date", "Total value locked ($)", "Five tokens total value locked", "center left", 0, 2, True)

# %%
files = [
    ("../csvData/depositRate/DAI-6m-Deposit rate-v2.csv", "b-"),
    ("../csvData/depositRate/USDC-6m-Deposit rate-v2.csv", "r-"),
    ("../csvData/depositRate/USDT-6m-Deposit rate-v2.csv", "g-"),
    ("../csvData/depositRate/WBTC-6m-Deposit rate-v2.csv", "k-"),
    ("../csvData/depositRate/WETH-6m-Deposit rate-v2.csv", "y-")
]
plot_multiple_files(files, "Date", "Deposit rate (%)", "Five tokens deposit rate", "center left", 0, 2, True)

# %%
files = [
    ("../csvData/depositRate/DAI-6m-Deposit rate-v2.csv", "b-"),
    ("../csvData/depositRate/USDC-6m-Deposit rate-v2.csv", "r-"),
    ("../csvData/depositRate/WBTC-6m-Deposit rate-v2.csv", "k-"),
    ("../csvData/depositRate/WETH-6m-Deposit rate-v2.csv", "y-")
]
plot_multiple_files(files, "Date", "Deposit rate (%)", "Four tokens deposit rate (without USDT)", "center left", 0, 2, True)
