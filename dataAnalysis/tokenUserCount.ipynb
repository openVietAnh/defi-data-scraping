# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import matplotlib.dates as md
from utils import plot_multiple_files

# %%
files = [
    ("../csvData/tokenUserCount/DAI.csv", "b-"),
    ("../csvData/tokenUserCount/USDC.csv", "r-"),
    ("../csvData/tokenUserCount/USDT.csv", "g-"),
    ("../csvData/tokenUserCount/WBTC.csv", "k-"),
    ("../csvData/tokenUserCount/WETH.csv", "y-")
]
plot_multiple_files(files, "Date", "User count", "Five tokens user count", "center left", 0, 1, True)

# %%
files = [
    ("../csvData/1-minute-mark/DAI-user.csv", "b-"),
    ("../csvData/1-minute-mark/USDC-user.csv", "r-"),
    ("../csvData/1-minute-mark/USDT-user.csv", "g-"),
    ("../csvData/1-minute-mark/WBTC-user.csv", "k-"),
    ("../csvData/1-minute-mark/WETH-user.csv", "y-")
]
plot_multiple_files(files, "Date", "User count", "Five tokens user count", "center left", 0, 1, True)
