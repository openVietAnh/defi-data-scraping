# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import matplotlib.dates as md
from utils import plot_single_file, plot_multiple_files

# %%
plot_single_file("../csvData/tokenPriceinUSD/WBTC-usd-price.csv", "Date", "Price ($)", "WBTC Price", "WBTC", "center left", 0, 1, False)

# %%
plot_single_file("../csvData/tokenPriceinUSD/WETH-usd-price.csv", "Date", "Price ($)", "WETH Price", "WETH", "center left", 0, 1, False)

# %%
files = [
    ("../csvData/tokenPriceinUSD/WETH-usd-price.csv", "b-"),
    ("../csvData/tokenPriceinUSD/WBTC-usd-price.csv", "r-"),
]
plot_multiple_files(files, "Date", "Price ($)", "WETH - WBTC Price comparison", "center left", 0, 1, False)

# %%
files = [
    ("../csvData/tokenPriceinUSD/DAI-usd-price.csv", "b-"),
    ("../csvData/tokenPriceinUSD/USDC-usd-price.csv", "r-"),
    ("../csvData/tokenPriceinUSD/USDT-usd-price.csv", "g-")
]
plot_multiple_files(files, "Date", "Price ($)", "Stable coin price comparison", "center left", 0, 1, False)
